# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
#ваш код здесь
hh_data = pd.read_csv('data/dst-3.0_16_1_hh_database.csv',sep=";")

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
#ваш код здесь
hh_data.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %%
hh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
#ваш код здесь
hh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
#ваш код здесь
hh_data.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
#ваш код здесь
def get_education(arg): # Cоздаем функцию для преобразования 
    arg = ' '.join(arg.split(' ')[:3])
    if 'Высшее' in arg:
        return 'высшее'
    elif 'Неоконченное высшее' in arg:
        return 'неоконченное высшее'
    elif 'Среднее специальное' in arg:
        return 'среднее специальное'
    elif 'Среднее образование' in arg:
        return 'среднее'
hh_data['Образование'] = hh_data['Образование и ВУЗ'].apply(get_education) # Применяем функцию к столбцу "Образование и ВУЗ"
hh_data['Образование'].unique() # Проверяем состав нового столбца "Образование"
hh_data = hh_data.drop('Образование и ВУЗ', axis=1) # Удаляем столбец "Образование и ВУЗ"

midle_education = hh_data['Образование'].value_counts()['среднее'] # Вычисляем количество соискателей со средним образованием 
print(f'Количество соискателей имеющих средний уровень образования равен: {midle_education}') # Выводим ответ
# Out:
# Количество соискателей имеющих средний уровень образования равен: 559

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
#ваш код здесь
def get_sex(arg):  # Cоздаем функцию для определния пола
    arg = ' '.join(arg.split(','))
    if 'Мужчина' in arg:
        return 'М'
    else:
        return 'Ж'
hh_data['Пол'] = hh_data['Пол, возраст'].apply(get_sex) # Применяем функцию к признаку "Пол, возраст"
hh_data['Пол'].unique() # Проверяем состав нового признака "Пол"

def get_age(arg): # Cоздаем функцию для определния возраста
    arg = ''.join(arg.split(',')[1])
    return int(arg[2:4])
hh_data['Возраст'] = hh_data['Пол, возраст'].apply(get_age) # Применяем функцию к признаку "Пол, возраст"
hh_data['Возраст'].unique() # Проверяем состав нового признака "Возраст"
hh_data = hh_data.drop('Пол, возраст', axis=1) #Удаляем признак "Пол, возраст"

# Вычисляем процент женских резюме и средний возраст соискателей
women_persent = (100*hh_data['Пол'].value_counts()['Ж']/ 
                 ((hh_data['Пол'].value_counts()['М']) + (hh_data['Пол'].value_counts()['Ж']))).round(2) 
print(f'Процент женских резюме равен: {women_persent}') # Выводим ответ

mean_age = (hh_data['Возраст'].mean()).round(1)
print(f'Cредний возраст соискателей равен: {mean_age}') # Выводим ответ
# Out:
# Процент женских резюме равен: 19.07
# Cредний возраст соискателей равен: 32.2

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
#ваш код здесь
def get_experience(arg):
    if arg is np.nan or arg == 'Не указано':
        return None
    year_words=['год', 'года', 'лет']
    month_words=['месяц', 'месяца', 'месяцев']
    arg_splitted = arg.split(' ')[:7]
    years = 0
    months = 0
    for index, item in enumerate (arg_splitted):
        if item in year_words:
            years = int(arg_splitted[index-1])
        if item in month_words:
            months = int(arg_splitted[index-1])
    return int(years*12 + months)
hh_data['Опыт работы (месяц)'] = hh_data['Опыт работы'].apply(get_experience) # Применяем функцию к признаку "Опыт работы"
hh_data['Опыт работы (месяц)'].unique() # Проверяем состав нового признака "Опыт работы"
hh_data = hh_data.drop('Опыт работы', axis=1) #Удаляем признак "Опыт работы"

median_exp = round(hh_data['Опыт работы (месяц)'].median()) # Вычисляем медианный опыт работы (в месяцах)
print(f'Медианный опыт работы (в месяцах) равен: {median_exp}') # Выводим ответ
# Out:
# Медианный опыт работы (в месяцах) равен: 100

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
#ваш код здесь
def get_city(arg):  # Cоздаем функцию для определния города
    million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград']
    arg = (arg.split(' ,'))
    if 'Москва' in arg:
        return 'Москва'
    elif 'Санкт-Петербург' in arg:
        return 'Санкт-Петербург'
    elif arg[0] in million_cities:
        return 'город-миллионник'
    else:
        return 'другие'
hh_data['Город'] = hh_data['Город, переезд, командировки'].apply(get_city) # Применяем функцию к признаку "Город, переезд, командировки"
hh_data['Город'].unique() # Проверяем состав нового признака "Пол"

spb_persent = (100*hh_data['Город'].value_counts()['Санкт-Петербург']/
               hh_data['Город'].count()).round() # Вычисляем процент соискателей живущих в Санкт-Петербурге
print(f'Процент соискателей живущих в Санкт-Петербурге равен: {spb_persent}') # Выводим ответ

def get_relocate(arg): # Cоздаем функцию для определния соискателей готовых к переезду в другой город
    arg = (arg.split(','))
    if 'м.' in arg[1]:
        if 'не' in arg[2][:4]:
            return False
        else:
            return True
    else:
        if 'не' in arg[1][:4]:
            return False
        else:
            return True
hh_data['Готовность к переезду'] = hh_data['Город, переезд, командировки'].apply(get_relocate) # Применяем функцию
hh_data['Готовность к переезду'].unique() # Проверяем состав нового признака "Готовность к переезду"

def get_business_trip(arg): # Cоздаем функцию для определния соискателей готовых к командировкам в другой город
    if ('командировка' in arg):
        if ('не готов к командировкам' in arg) or('не готова к командировкам' in arg):
            return False
        else: 
            return True
    else:
        return False
hh_data['Готовность к командировкам'] = hh_data['Город, переезд, командировки'].apply(get_business_trip) # Применяем функцию
hh_data['Готовность к командировкам'].unique() # Проверяем состав нового признака "Готовность к командировкам"

hh_data = hh_data.drop('Город, переезд, командировки', axis=1) #Удаляем признак "Город, переезд, командировки"

mask_1 = hh_data[(hh_data['Готовность к переезду'] == True) & (hh_data['Готовность к командировкам'] == True)].count()
result = (100*(mask_1['Готовность к командировкам'].sum())/hh_data['График'].count()).round() #Вычисляем процент готовых и к переезду и к командировкам
print(f'Процент соискателей готовых и к переезду и к командировкам равен: {result}') # Выводим ответ
# Out:
# Процент соискателей живущих в Санкт-Петербурге равен: 11.0
# Процент соискателей готовых и к переезду и к командировкам равен: 32.0

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
#ваш код здесь
def get_employment_1(arg): # Cоздаем функцию для определния категории занятости 'полная занятость'
    arg_splitted = arg.split(', ')
    if 'полная занятость' in arg_splitted: 
        return True
    else:
        return False
hh_data['полная занятость'] = hh_data['Занятость'].apply(get_employment_1) # Применяем функцию

def get_employment_2(arg): # Cоздаем функцию для определния категории занятости 'частичная занятость'
    arg_splitted = arg.split(', ')
    if 'частичная занятость' in arg_splitted: 
        return True
    else:
        return False
hh_data['частичная занятость'] = hh_data['Занятость'].apply(get_employment_2) # Применяем функцию

def get_employment_3(arg): # Cоздаем функцию для определния категории занятости 'проектная работа'
    arg_splitted = arg.split(', ')
    if 'проектная работа' in arg_splitted: 
        return True
    else:
        return False
hh_data['проектная работа'] = hh_data['Занятость'].apply(get_employment_3) # Применяем функцию

def get_employment_4(arg): # Cоздаем функцию для определния категории занятости 'волонтёрство'
    arg_splitted = arg.split(', ')
    if 'волонтерство' in arg_splitted: 
        return True
    else:
        return False
hh_data['волонтерство'] = hh_data['Занятость'].apply(get_employment_4) # Применяем функцию

def get_employment_5(arg): # Cоздаем функцию для определния категории занятости 'стажировка'
    arg_splitted = arg.split(', ')
    if 'стажировка' in arg_splitted: 
        return True
    else:
        return False
hh_data['стажировка'] = hh_data['Занятость'].apply(get_employment_5) # Применяем функцию



def get_schedule_1(arg): # Cоздаем функцию для определния категории графика работы 'полный день'
    arg_splitted = arg.split(', ')
    if 'полный день' in arg_splitted: 
        return True
    else:
        return False
hh_data['полный день'] = hh_data['График'].apply(get_schedule_1) # Применяем функцию

def get_schedule_2(arg): # Cоздаем функцию для определния категории графика работы 'сменный график'
    arg_splitted = arg.split(', ')
    if 'сменный график' in arg_splitted: 
        return True
    else:
        return False
hh_data['сменный график'] = hh_data['График'].apply(get_schedule_2) # Применяем функцию

def get_schedule_3(arg): # Cоздаем функцию для определния категории графика работы 'гибкий график'
    arg_splitted = arg.split(', ')
    if 'гибкий график' in arg_splitted: 
        return True
    else:
        return False
hh_data['гибкий график'] = hh_data['График'].apply(get_schedule_3) # Применяем функцию

def get_schedule_4(arg): # Cоздаем функцию для определния категории графика работы 'удалённая работа'
    arg_splitted = arg.split(', ')
    if 'удалённая работа' in arg_splitted: 
        return True
    else:
        return False
hh_data['удалённая работа'] = hh_data['График'].apply(get_schedule_4) # Применяем функцию

def get_schedule_5(arg): # Cоздаем функцию для определния категории графика работы 'вахтовый метод'
    arg_splitted = arg.split(', ')
    if 'вахтовый метод' in arg_splitted: 
        return True
    else:
        return False
hh_data['вахтовый метод'] = hh_data['График'].apply(get_schedule_5) # Применяем функцию

mask_2 = hh_data[(hh_data['проектная работа'] == True) & (hh_data['волонтерство'] == True)] # Вычисляем соискателей ищущих проектную работу и волонтёрство
result_1 = mask_2['Город'].count()
mask_3 = hh_data[(hh_data['гибкий график'] == True) & (hh_data['вахтовый метод'] == True)] # Ищем соискателей желающих работать вахтой с гибким графиком
result_2 = mask_3['Город'].count()

hh_data = hh_data.drop('Занятость', axis=1)
hh_data = hh_data.drop('График', axis=1)

print(f'Количество соискателей ищущих проектную работу и волонтёрство равно: {result_1}') # Выводим ответ
print(f'Количество соискателей желающих работать вахтовым методом и с гибким графиком равно: {result_2}') # Выводим ответ
# Out:
# Количество соискателей ищущих проектную работу и волонтёрство равно: 436
# Количество соискателей желающих работать вахтовым методом и с гибким графиком равно: 2311

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
#ваш код здесь
cur_data = pd.read_csv('data/ExchangeRates.csv') # Загружаем в датафрейм данные о курсах валют
cur_data['date'] = pd.to_datetime(cur_data['date'], dayfirst=True) # Приводим признак 'date' к формату datetime
cur_data['date'] = cur_data['date'].dt.date # Выделяем только дату в признаке 'Обновление резюме'

hh_data['Обновление резюме'] = pd.to_datetime(hh_data['Обновление резюме'], dayfirst=True) # Приводим признак 'Обновление резюме' к формату datetime 
hh_data['Обновление резюме'] = hh_data['Обновление резюме'].dt.date # Выделяем только дату в признаке 'Обновление резюме'

cur_data_2 = cur_data.copy() # Работаем в копиях
hh_data_2 = hh_data.copy() # Работаем в копиях

def get_payment(arg): # Cоздаем функцию для выделения суммы зарплаты
    arg_splitted = arg.split(' ')
    return arg_splitted[0]
    
hh_data_2['ЗП сумма'] = hh_data_2['ЗП'].apply(get_payment) # Применяем функцию

def get_curency(arg): # Cоздаем функцию для выделения валюты зарплаты
    arg_splitted = arg.split(' ')
    return arg_splitted[1]

hh_data_2['ЗП валюта'] = hh_data_2['ЗП'].apply(get_curency) # Применяем функцию

def get_iso(arg): # Cоздаем функцию для преобразования валюты зарплаты к ISO кодировке
    if arg == 'грн.':
        return 'UAH'
    elif arg == 'USD':
        return 'USD'
    elif arg == 'EUR':
        return 'EUR'
    elif arg == 'бел.руб.':
        return 'BYN'
    elif arg == 'KGS':
        return 'KGS'
    elif arg == 'сум':
        return 'UZS'
    elif arg == 'AZN':
        return 'AZN'
    elif arg == 'KZT':
        return 'KZT'
    elif arg == 'руб.':
        return 'RUB'

hh_data_2['ЗП валюта ISO'] = hh_data_2['ЗП валюта'].apply(get_iso) # Применяем функцию

hh_data_2_merged = hh_data_2.merge(
    cur_data_2,
    left_on=['ЗП валюта ISO', 'Обновление резюме'],
    right_on=['currency', 'date'],
    how='left'
) # Объединяем 2 датафрейма

hh_data_2_merged.loc[hh_data_2_merged['ЗП валюта ISO'] == 'RUB', 'close'] = 1 # Заменяем значение 'close' для 'RUB'
hh_data_2_merged.loc[hh_data_2_merged['ЗП валюта ISO'] == 'RUB', 'proportion'] = 1 # Заменяем значение 'proportion' для 'RUB'

hh_data_2_merged['ЗП сумма'] = hh_data_2_merged['ЗП сумма'].astype (float) # Приводим признак 'ЗП сумма' к формату float
hh_data_2_merged['ЗП (руб)'] = hh_data_2_merged['ЗП сумма']*hh_data_2_merged['close']/hh_data_2_merged['proportion'] # Создаем признак 'ЗП (руб)'
result = hh_data_2_merged['ЗП (руб)'].median() 
print(f'Желаемая медианная заработная плата соискателей равна: {result}') # Выводим ответ

hh_data = hh_data_2_merged.copy() # Перезаписываем датафрейм

hh_data = hh_data.drop('proportion', axis=1) # Удаляем не нужные столбцы
hh_data = hh_data.drop('vol', axis=1)
hh_data = hh_data.drop('close', axis=1)
hh_data = hh_data.drop('time', axis=1)
hh_data = hh_data.drop('date', axis=1)
hh_data = hh_data.drop('per', axis=1)
hh_data = hh_data.drop('currency', axis=1)
hh_data = hh_data.drop('ЗП валюта ISO', axis=1)
hh_data = hh_data.drop('ЗП валюта', axis=1)
hh_data = hh_data.drop('ЗП сумма', axis=1)
hh_data = hh_data.drop('ЗП', axis=1)
hh_data.info()
# Out:
# Желаемая медианная заработная плата соискателей равна: 59019.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44744 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44744 non-null  object
#  1   Последнее/нынешнее место работы  44743 non-null  object
#  2   Последняя/нынешняя должность     44742 non-null  object
#  3   Обновление резюме                44744 non-null  object
#  4   Авто                             44744 non-null  object
#  5   Образование                      44744 non-null  object
#  6   Пол                              44744 non-null  object
#  7   Возраст                          44744 non-null  int64
#  8   Опыт работы (месяц)              44574 non-null  float64
#  9   Город                            44744 non-null  object
#  10  Готовность к переезду            44744 non-null  bool
# ...

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 4)) # Создаем фигуру для 2 диаграмм
histplot = sns.histplot(data=hh_data, x='Возраст', ax=axes[0]); # Строим гистограмму
histplot.set_title('Распределние соискателей на hh по возрасту'); 
boxplot = sns.boxplot(data=hh_data, x='Возраст', ax=axes[1]); # Строим коробчатую диаграмму
boxplot.set_title('Распределние соискателей на hh по возрасту'); 

result = hh_data_2_merged['Возраст'].mode(1)
print(f'Мода признака Возраст равна: {result} лет') # Выводим ответ
# Out:
# Мода признака Возраст равна: 0    30
# Name: Возраст, dtype: int64 лет

# %% [markdown]
# ваши выводы по графику здесь:
#
# На графиках мы видим, что наиболее частый возраст это 30 лет и большинству соискателей от 27 до 37 лет.
#
# На графике явно присутствуют аномалии, а именно кандидат с возрастом 10 лет. Согласно ТК РФ, работать человек может с 16 лет. Поэтому все соискатели младше 16 лет являются аномалиями.
# анамалиями н
# С другой стороны соискатели, которым около 80 лет, тоже староваты для поиска работы.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 4)) # Создаем фигуру для 2 диаграмм
histplot = sns.histplot(data=hh_data, x='Опыт работы (месяц)', ax=axes[0], color='green'); # Строим гистограмму 
histplot.set_title('Распределние соискателей на hh по опыту работы в месяцах'); 
boxplot = sns.boxplot(data=hh_data, x='Опыт работы (месяц)', ax=axes[1], color='green'); # Строим коробчатую диаграмму 
boxplot.set_title('Распределние соискателей на hh по опыту работы в месяцах'); 

hh_data_2_merged['Опыт работы (месяц)'].mode()
hh_data_2_merged['Опыт работы (месяц)'].max()
# Out:
# 1188.0

# %% [markdown]
# ваши выводы здесь:
#
# Наиболее часто встречаются соискатели с опытом работы 81 месяц (почти 7 лет) а большинство кандидатов находится в промежутке 60 - 160 месяцев (от 5 до 13 лет).
#
# Явно присутствуют аномалии, которые портят информативность наших графиков. Аномалия опыт работы близкий к 100 годам. Похоже на ошибку в данных.
#
# Максимальное значение в признаке составляет 1188 месяцев, что и является анамалией.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 4)) # Создаем фигуру для 2 диаграмм
histplot = sns.histplot(data=hh_data, x='ЗП (руб)', ax=axes[0], color='pink'); # Строим гистограмму 
histplot.set_title('Распределние соискателей на hh по размеру желаемой зарплаты'); 
boxplot = sns.boxplot(data=hh_data, x='ЗП (руб)', ax=axes[1], color='pink'); # Строим коробчатую диаграмму 
boxplot.set_title('Распределние соискателей на hh по размеру желаемой зарплаты');

# %%
hh_data['ЗП (руб)'].describe()
# Out:
# count    4.474400e+04
# mean     7.653354e+04
# std      1.359315e+05
# min      1.000000e+00
# 25%      3.708220e+04
# 50%      5.901900e+04
# 75%      9.500000e+04
# max      2.430488e+07
# Name: ЗП (руб), dtype: float64

# %% [markdown]
# ваши выводы здесь:
#
# Самая частая желаемая зарплата - 50 000 руб.
#
# Основная масса соискателей желает зарплату от 37 000 руб до 95 000 руб. Предедльные значения от 1 руб до 24304880 руб.
#
# Предельные значения признака явно являются аномалией. При этом максимальное значение на столько сплющивает график, что по нему вообще никаких выводов нельзя сделать

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# ваш код здесь
mask_4 = hh_data[hh_data['ЗП (руб)'] < 1000000]
hh_data_group = mask_4.groupby('Образование')['ЗП (руб)'].median() # группируем медианную зп по признаку
hh_data_group

fig = px.bar( # строим столбчатую диаграмму
    data_frame=hh_data_group, 
    orientation='v', 
    height=500, 
    width=1000, 
    title='Зависимость медианной зарплаты от уровня образования' 
)

fig.show()

# %% [markdown]
# ваши выводы здесь:
#
# Наименьший медианный уровень ожидаемой зарплаты у 2х категорий - среднее и среднее специальное (40000 руб) Наибольший уровень у кандидатов с высшим образованием (60000 руб), Соискатели с неоконченным высшим в середине с медианным уровнем зарплаты  в 50000 руб.
#
# При прогнозировании зарплаты, признак уровень образования безусловно важен. Чем выше уровень образования, тем желаемая зарплата выше.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# ваш код здесь
mask_5 = hh_data[hh_data['ЗП (руб)'] < 1000000]
hh_data_group = mask_5.groupby('Город')['ЗП (руб)'].median() # группируем медианную зп по признаку

fig = px.bar(  # строим столбчатую диаграмму
    data_frame=hh_data_group, 
    orientation='v', 
    height=500, 
    width=1000, 
    title='Зависимость медианной зарплаты от города' 
)

fig.show()

fig = plt.figure(figsize=(11, 7)) # строим коробчатую диаграмму
boxplot = sns.boxplot(
    data=mask_5,
    y='Город',
    x='ЗП (руб)',
    width=0.4
)
boxplot.set_title('Зависимость ожидаемой зарплаты от города проживания кандидата');
boxplot.set_xlabel('Размер желаемой зарплаты');
boxplot.set_ylabel('Города');
boxplot.grid()

# %% [markdown]
# ваши выводы здесь:
#
# Медианное значение и размах в городах миллионниках (без Москвы и Санкт-Петербурга) и других городах практически одинаковые. То есть в рамках нашей модели не так важно в обычном городе живет человек или в городах-милионниках.
#
# В Санкт-Петербурге ожидаемая зарплата выше чем в вышеуказанных категориях, но максимальное медианное значение и размах ожидаемо в столице РФ Москве
#
# Признак 'Город' однозначно очень важен при прогнозировании зарплаты.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
# ваш код здесь
mask_5 = hh_data[hh_data['ЗП (руб)'] < 1000000]
hh_data_group = mask_5.groupby(['Готовность к переезду','Готовность к командировкам'], as_index=False)['ЗП (руб)'].median()

hh_data_group = hh_data.groupby( # группируем медианную зп по признакам
    ['Готовность к командировкам', 'Готовность к переезду'],
    as_index=False
)['ЗП (руб)'].median()

fig = px.bar( # рисуем многоуровневую столбчатую диаграмму
    data_frame=hh_data_group,
    y='ЗП (руб)',
    x='Готовность к переезду',
    barmode="group",
    color='Готовность к командировкам',
    orientation='v',
    title='Медианная зарплата по готовности к командировкам/переезду'
)
fig.show()

# %% [markdown]
# ваши выводы здесь:
#
# Уровень желаемой зарплаты сосискателей готовых к переезду выше, чем у кандидатов, не желающих переезжать.
# При этом среди тех и тех, готовность к командировкам значительно завышает ожидаемую зарплату.
#
# Данные признаки так же оказывают значительное влияние в рамках определения уровня зарплаты.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# ваш код здесь
mask_5 = hh_data[hh_data['ЗП (руб)'] < 1000000]
pivot = mask_5.pivot_table( # создаем сводную таблицу
    values='ЗП (руб)',
    columns='Возраст',
    aggfunc='median',
    index='Образование',
    fill_value=0
)
pivot.columns = pivot.columns.astype('string')
pivot_heatmap = sns.heatmap( # рисуем тепловую карту
    pivot,
    linewidth=0,
    linecolor='w',
    cmap='crest'
    )
pivot_heatmap.set_title('Зависимость медианной желаемой з/п от возраста и образования');
pivot_heatmap.set_xlabel('Возвраст');
pivot_heatmap.set_ylabel('Уровень образования');

# %% [markdown]
# ваши выводы здесь:
#
# На тепловой карте выделяется область высшего образования у соискателей от 27 до 55 лет. и неоконченное высшее от 40 до 50 лет. В этих промежутках соискатели желают наиболее высокую зарплату.
#
# Среднее и среднее специальное с увеличением возраста уровень желаемой зп меняется не значительно.
# Для модели данная информация полезная.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# ваш код здесь

hh_data_3 = hh_data.copy()
hh_data_3['Опыт работы, лет'] = hh_data_3['Опыт работы (месяц)'].apply(lambda x: x/12)

fig = plt.figure(figsize=(10, 5)) # рисуем диаграмму рассеивания
sns.lineplot(x=[0, 100], y=[0, 100], size=1, color='red')
scatterplot = sns.scatterplot(
    data=hh_data_3,
    x='Опыт работы, лет',
    y='Возраст',
    s=10,
    sizes=(50, 300)

)
scatterplot.set_title('Взаимосвязь опыта работы и возраста', fontsize=16);
scatterplot.set_xlabel('Опыт работы, лет');
scatterplot.set_ylabel('Возраст, лет');

# %% [markdown]
# ваши выводы здесь:
#
# На данной диаграмме видно все 7 выбросов: соискателей чей возраст меньше чем их опыт.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# ваш код здесь
mask_5 = hh_data_3[hh_data_3['ЗП (руб)'] < 250000] # Отсекаем условные выбросы для наглядности графика
mask_5 = mask_5[mask_5['Опыт работы, лет'] < 50]

fig = plt.figure(figsize=(10, 5)); # рисуем диаграмму рассеивания
scatterplot = sns.scatterplot(
    data=mask_5,
    x='Опыт работы, лет',
    y='ЗП (руб)',
    s=10,
    hue='Пол',
    sizes=(50, 300),
    );
scatterplot.set_title('Взаимосвязь ЗП, пола и опыта работы', fontsize=16);
scatterplot.set_xlabel('Опыт работы, лет');
scatterplot.set_ylabel('ЗП (руб)');
scatterplot.grid();

#отображаем его
fig.show()

fig = plt.figure(figsize=(11, 5));  # рисуем коробчатую диаграмму
boxplot = sns.boxplot(
    data=mask_5,
    y='Пол',
    x='ЗП (руб)',
    width=0.4
);
boxplot.set_title('Распределние ожидаемой зарплаты в зависимости от пола соискателя');
boxplot.set_xlabel('Ожидаемая зарплата');
boxplot.set_ylabel('Пол');
boxplot.grid();
# Out:
# C:\Users\Евгений\AppData\Local\Temp\ipykernel_15976\1171912124.py:20: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ваши выводы здесь:
#
# Соискатели женского пола чаще претендуют на более низкую зарплату чем мужчины. При этом на диаграмме рассеивания мы видим что, даже при увеличении опыта размер желаемой зарплаты глобально не меняется.
#
# Большинство женщин желают получать 45 тыс. У мужчин эта цифра составлет около 60 тыс руб.

# %%
# ваш код здесь
mask_5 = hh_data[hh_data['ЗП (руб)'] < 1000000]

hh_data_group = mask_5.groupby( # группируем медианную зарплату по булевым признакам полная занятость, полный день
    ['полная занятость', 'полный день'],
    as_index=False
)['ЗП (руб)'].median()
fig = px.bar(  # рисуем многоуровневую столбчатую диаграмму
    data_frame=hh_data_group,
    y='ЗП (руб)',
    x='полная занятость',
    barmode="group",
    color='полный день',
    orientation='v',
    title='Медианная зарплата по готовности работать полный день при полной занятости'
)

fig.show() # рвыводим диаграмму на экран

# %% [markdown]
# ваши выводы здесь:
#
# Самая высокая ожидаемая зарплата у соискателей готовых работать полный день на полном занятости. Остальные категории указывают зарплату значительно меньше, что может быть полезно для нашей модели.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# ваш код здесь
mask_6 = hh_data.duplicated() # ищем дубликаты
hh_duplicates = hh_data[mask_6]
hh_data = hh_data.drop_duplicates()  # удаляем дубликаты
print(f'Число найденных дубликатов: {hh_duplicates.shape[0]}')
# Out:
# Число найденных дубликатов: 161

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# ваш код здесь
cols_null = hh_data.isnull().sum() #применяем функцию isnull()
cols_with_null = cols_null.sort_values(ascending=False) # Считаем сумму пропусков по признакам
display(cols_with_null) # Выводим
# Out:
# Опыт работы (месяц)                168
# Последняя/нынешняя должность         2
# Последнее/нынешнее место работы      1
# Ищет работу на должность:            0
# частичная занятость                  0
# вахтовый метод                       0
# удалённая работа                     0
# гибкий график                        0
# сменный график                       0
# полный день                          0
# стажировка                           0
# волонтерство                         0
# проектная работа                     0
# Готовность к командировкам           0
# полная занятость                     0
# Готовность к переезду                0
# Город                                0
# Возраст                              0
# Пол                                  0
# Образование                          0
# Авто                                 0
# Обновление резюме                    0
# ЗП (руб)                             0
# dtype: int64

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# ваш код здесь
drop_index = list(hh_data[hh_data.isnull()['Последняя/нынешняя должность'] == True].index.values.astype(int)) # Вычисляем индексы строк с пропусками
hh_data = hh_data.drop(axis=0, index=drop_index) # Удаляем строки по полученным индексам


values = { #создаем словарь имя столбца: число(признак) на который надо заменить пропуски
    'Опыт работы (месяц)': hh_data['Опыт работы (месяц)'].median(),
    }
hh_data = hh_data.fillna(values) #заполняем пропуски в соответствии с заявленным словарем

cols_null = hh_data.isnull().sum() #применяем функцию isnull()
cols_with_null = cols_null.sort_values(ascending=False) # Считаем сумму пропусков по признакам
display(cols_with_null) # Выводим 
result = hh_data['Опыт работы (месяц)'].mean().round()
print(f'результирующее среднее значение в столбце Опыт работы (месяц) равно: {result}')
# Out:
# Ищет работу на должность:          0
# полная занятость                   0
# вахтовый метод                     0
# удалённая работа                   0
# гибкий график                      0
# сменный график                     0
# полный день                        0
# стажировка                         0
# волонтерство                       0
# проектная работа                   0
# частичная занятость                0
# Готовность к командировкам         0
# Последнее/нынешнее место работы    0
# Готовность к переезду              0
# Город                              0
# Опыт работы (месяц)                0
# Возраст                            0
# Пол                                0
# Образование                        0
# Авто                               0
# Обновление резюме                  0
# Последняя/нынешняя должность       0
# ЗП (руб)                           0
# dtype: int64
# результирующее среднее значение в столбце Опыт работы (месяц) равно: 114.0

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# ваш код здесь
outliers = hh_data[hh_data['ЗП (руб)'] < 1000] # Определяем выбросы в ручную
outliers_2 = hh_data[hh_data['ЗП (руб)'] > 1000000]
result = outliers.shape[0] + outliers_2.shape[0] 
print(f'Найденное число выбросов равно: {result}') # Выводим ответ на вопрос

hh_data = hh_data.drop(outliers.index, axis=0)
hh_data = hh_data.drop(outliers_2.index, axis=0) # Удаляем выбросы
# Out:
# Найденное число выбросов равно: 89

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# ваш код здесь
outliers = hh_data[(hh_data['Опыт работы (месяц)'])/12 > hh_data['Возраст']] # Определяем выбросы в ручную
result = outliers.shape[0]
print(f'Найденное число выбросов равно: {result}') # Выводим ответ на вопрос
hh_data = hh_data.drop(outliers.index, axis=0) # Удаляем выбросы
# Out:
# Найденное число выбросов равно: 7

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
# ваш код здесь # Создаем функцию поиска выбросов методом сигм
def outliers_z_score_mod(data, feature, left=3, right=3, log_scale=False):
    if log_scale:
        x = np.log(data[feature]+1)
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x >= lower_bound) & (x <= upper_bound)]
    return outliers, cleaned

outliers, cleaned = outliers_z_score_mod(hh_data, 'Возраст', right=4, log_scale=True) # Приминяем функцию
print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')

fig, ax = plt.subplots(1, 1, figsize=(8, 4)) # Рисуем график
log_age = np.log(hh_data['Возраст'])
histplot = sns.histplot(log_age, bins=30, ax=ax)
histplot.axvline(log_age.mean(), color='k', lw=2)
histplot.axvline(log_age.mean()+ 3 * log_age.std(), color='k', ls='--', lw=2)
histplot.axvline(log_age.mean()- 3 * log_age.std(), color='k', ls='--', lw=2)
histplot.set_title('Распределение логорифмированного признака Возраст');

display(outliers) #Выводим выбросы

hh_data = hh_data.drop(outliers.index, axis=0) #Удаляем выбросы
# Out:
# Число выбросов по методу z-отклонения: 3
# Результирующее число записей: 44482
#             Ищет работу на должность: Последнее/нынешнее место работы  \
# 31137  Менеджер по работе с клиентами           ООО "ФёрстКэшКомпани"
# 32950                 Тестировщик игр                        OOO ЖМЫХ
# 33654            Frontend-разработчик                       Freelance
#
#          Последняя/нынешняя должность Обновление резюме        Авто  \
# 31137  Менеджер по работе с клиентами        2019-04-06  Не указано
# 32950                  Тестировщик ПО        2019-04-09  Не указано
# 33654            Frontend-разработчик        2019-04-19  Не указано
#
#                Образование Пол  Возраст  Опыт работы (месяц)            Город  \
# 31137              среднее   М       15                  2.0  Санкт-Петербург
# 32950  среднее специальное   М       15                  3.0           другие
# 33654  среднее специальное   М       10                 30.0  Санкт-Петербург
#
# ...

# %% [markdown]
# ваш коммментарий здесь:
#
# На графике видна правая ассиметрия. Поэтому послабление в одну сигму в право вполне оправдано.
# Оставшиеся три выброса, это резюме с возрастом менее 16 лет.
