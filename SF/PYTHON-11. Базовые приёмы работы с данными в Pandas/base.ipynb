# %%
import pandas as pd

melb_data = pd.read_csv('data/melb_data_ps.csv', sep=',')
melb_data.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_df = melb_data.copy()
melb_df.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_df = melb_df.drop(['index', 'Coordinates'], axis=1)
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5      3067  ...         1    1     202.0         126.0
# 1  4/02/2016       2.5      3067  ...         1    0     156.0          79.0
# 2  4/03/2017       2.5      3067  ...         2    0     134.0         150.0
# 3  4/03/2017       2.5      3067  ...         2    1      94.0         126.0
# 4  4/06/2016       2.5      3067  ...         1    2     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
display(melb_df['Date'])
# Out:
# 0         3/12/2016
# 1         4/02/2016
# 2         4/03/2017
# 3         4/03/2017
# 4         4/06/2016
#             ...
# 13575    26/08/2017
# 13576    26/08/2017
# 13577    26/08/2017
# 13578    26/08/2017
# 13579    26/08/2017
# Name: Date, Length: 13580, dtype: object

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)
display(melb_df['Date'])
# Out:
# 0       2016-12-03
# 1       2016-02-04
# 2       2017-03-04
# 3       2017-03-04
# 4       2016-06-04
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
years_sold = melb_df['Date'].dt.year
print(years_sold)
print('Min year sold:', years_sold.min())
print('Max year sold:', years_sold.max())
print('Mode year sold:', years_sold.mode()[0])
# Out:
# 0        2016
# 1        2016
# 2        2017
# 3        2017
# 4        2016
#          ...
# 13575    2017
# 13576    2017
# 13577    2017
# 13578    2017
# 13579    2017
# Name: Date, Length: 13580, dtype: int64
# Min year sold: 2016
# Max year sold: 2017
# Mode year sold: 2017

# %%
melb_df['MonthSale'] = melb_df['Date'].dt.month
melb_df['MonthSale'].value_counts(normalize=True)
# Out:
# 5     0.149411
# 7     0.145950
# 9     0.135862
# 6     0.134757
# 8     0.114138
# 11    0.082032
# 4     0.069882
# 3     0.049926
# 12    0.044698
# 10    0.040574
# 2     0.032622
# 1     0.000147
# Name: MonthSale, dtype: float64

# %%
delta_days = melb_df['Date'] - pd.to_datetime('2016-01-01') 
display(delta_days)
# Out:
# 0       337 days
# 1        34 days
# 2       428 days
# 3       428 days
# 4       155 days
#           ...
# 13575   603 days
# 13576   603 days
# 13577   603 days
# 13578   603 days
# 13579   603 days
# Name: Date, Length: 13580, dtype: timedelta64[ns]

# %%
display(delta_days.dt.days)
# Out:
# 0        337
# 1         34
# 2        428
# 3        428
# 4        155
#         ...
# 13575    603
# 13576    603
# 13577    603
# 13578    603
# 13579    603
# Name: Date, Length: 13580, dtype: int64

# %%
melb_df['AgeBuilding'] = melb_df['Date'].dt.year - melb_df['YearBuilt']
display(melb_df['AgeBuilding'])
# Out:
# 0         46
# 1        116
# 2        117
# 3         47
# 4          2
#         ...
# 13575     36
# 13576     22
# 13577     20
# 13578     97
# 13579     97
# Name: AgeBuilding, Length: 13580, dtype: int64

# %%
melb_df = melb_df.drop('YearBuilt', axis=1)

# %%
melb_df['WeekdaySale'] = melb_df['Date'].dt.dayofweek
weekend_count = len(melb_df[melb_df['WeekdaySale'] == 5]) + len(melb_df[melb_df['WeekdaySale'] == 6])
display(weekend_count)
# Out:
# 12822

# %%
total_rooms = melb_df['Rooms'] + melb_df['Bedroom'] + melb_df['Bathroom']
display(total_rooms)
# Out:
# 0         5
# 1         5
# 2         8
# 3         8
# 4         8
#          ..
# 13575    10
# 13576     8
# 13577     8
# 13578     9
# 13579     9
# Length: 13580, dtype: int64

# %%
melb_df['MeanRoomsSquare'] = melb_df['BuildingArea'] / total_rooms
display(melb_df['MeanRoomsSquare'])
# Out:
# 0        25.200000
# 1        15.800000
# 2        18.750000
# 3        15.750000
# 4        17.750000
#            ...
# 13575    12.600000
# 13576    16.625000
# 13577    15.750000
# 13578    17.444444
# 13579    12.444444
# Name: MeanRoomsSquare, Length: 13580, dtype: float64

# %%
diff_area = melb_df['BuildingArea'] - melb_df['Landsize']
sum_area = melb_df['BuildingArea'] + melb_df['Landsize']
melb_df['AreaRatio'] = diff_area/sum_area
display(melb_df['AreaRatio'])
# Out:
# 0       -0.231707
# 1       -0.327660
# 2        0.056338
# 3        0.145455
# 4        0.083969
#            ...
# 13575   -0.676093
# 13576   -0.429185
# 13577   -0.551601
# 13578   -0.693060
# 13579   -0.527426
# Name: AreaRatio, Length: 13580, dtype: float64

# %%
melb_df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'CouncilArea', 'Lattitude', 'Longtitude',
#        'Regionname', 'Propertycount', 'MonthSale', 'AgeBuilding',
#        'WeekdaySale', 'MeanRoomsSquare', 'AreaRatio'],
#       dtype='object')

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})
countries_df['density'] = (countries_df['population'] * 1000000) / countries_df['square']
display(countries_df)
countries_df['density'].mean()
# Out:
#      country  population    square     density
# 0     Англия       56.29    133396  421.976671
# 1     Канада       38.05   9984670    3.810842
# 2        США      322.28   9826630   32.796595
# 3     Россия      146.24  17125191    8.539467
# 4    Украина       45.50    603628   75.377550
# 5   Беларусь        9.50    207600   45.761079
# 6  Казахстан       17.04   2724902    6.253436
# 84.93080566562001

# %%
def max_digit(value: int) -> int:
    str_value = str(value)
    digits = []
    for symbol in str_value:
        digits.append(int(symbol))
    return max(digits)


print("Example:")
print(max_digit(10))
# Out:
# Example:
# 1

# %%
import numpy as np
password = 'aaaaaabbbbb'
#new_password = list(password)
#new_password
#password.replace('', ' ')
##password_1 = password.split(' ')
len(np.unique(list(password)))
# Out:
# 2

# %%
ufo_usa_data = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv', sep=',')
display(ufo_usa_data)
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo_usa_data['Time'] = pd.to_datetime(ufo_usa_data['Time'])
display(ufo_usa_data)
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time
# 0     1930-06-01 22:00:00
# 1     1930-06-30 20:00:00
# 2     1931-02-15 14:00:00
# 3     1931-06-01 13:00:00
# 4     1933-04-18 19:00:00
# ...

# %%
years_ufo = ufo_usa_data['Time'].dt.year
print(years_ufo.value_counts())
# Out:
# 1999    2774
# 2000    2635
# 1998    1743
# 1995    1344
# 1997    1237
#         ...
# 1936       2
# 1930       2
# 1935       1
# 1934       1
# 1933       1
# Name: Time, Length: 68, dtype: int64

# %%
nv_ufo = ufo_usa_data[ufo_usa_data['State'] == 'NV']
nv_ufo.sort_values(by='Time', inplace=True)
days_ufo_nv = nv_ufo['Time'].dt.date.diff()
display(days_ufo_nv.dt.days.mean())
# Out:
# C:\Users\Евгений\AppData\Local\Temp\ipykernel_10448\1194301380.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nv_ufo.sort_values(by='Time', inplace=True)
# 68.92932862190813

# %%
print(melb_df['Address'].nunique())
# Out:
# 13378

# %%
print(melb_df['Address'].loc[177])
print(melb_df['Address'].loc[1812])
print(melb_df['Address'].loc[9001])
# Out:
# 2/119 Railway St N
# 9/400 Dandenong Rd
# 172 Danks St

# %%
# На вход данной функции поступает строка с адресом.
def get_street_type(address):
# Создаём список географических пометок exclude_list.
    exclude_list = ['N', 'S', 'W', 'E']
# Метод split() разбивает строку на слова по пробелу.
# В результате получаем список слов в строке и заносим его в переменную address_list.
    address_list = address.split(' ')
# Обрезаем список, оставляя в нём только последний элемент,
# потенциальный подтип улицы, и заносим в переменную street_type.
    street_type = address_list[-1]
# Делаем проверку на то, что полученный подтип является географической пометкой.
# Для этого проверяем его на наличие в списке exclude_list.
    if street_type in exclude_list:
# Если переменная street_type является географической пометкой,
# переопределяем её на второй элемент с конца списка address_list.
        street_type = address_list[-2]
# Возвращаем переменную street_type, в которой хранится подтип улицы.
    return street_type

# %%
street_types = melb_df['Address'].apply(get_street_type)
display(street_types)
# Out:
# 0        St
# 1        St
# 2        St
# 3        La
# 4        St
#          ..
# 13575    Cr
# 13576    Dr
# 13577    St
# 13578    St
# 13579    St
# Name: Address, Length: 13580, dtype: object

# %%
print(street_types.nunique())
# 56
# Out:
# 56

# %%
display(street_types.value_counts())
# Out:
# St           8012
# Rd           2825
# Ct            612
# Dr            447
# Av            321
# Gr            311
# Pde           211
# Pl            169
# Cr            152
# Cl            100
# La             67
# Bvd            53
# Tce            47
# Wy             40
# Avenue         40
# Cct            25
# Hwy            24
# Parade         15
# Boulevard      13
# Sq             11
# Crescent        9
# Cir             7
# Strand          7
# Esplanade       6
# Grove           5
# Gdns            4
# Grn             4
# Fairway         4
# Mews            4
# Crossway        3
# Righi           3
# Victoria        2
# Ridge           2
# Crofts          2
# Esp             2
# Glade           1
# Gra             1
# Ave             1
# Woodland        1
# Outlook         1
# Hts             1
# Highway         1
# Athol           1
# Summit          1
# Grand           1
# Res             1
# Nook            1
# Eyrie           1
# Dell            1
# East            1
# ...

# %%
popular_stypes =street_types.value_counts().nlargest(10).index
print(popular_stypes)
# Out:
# Index(['St', 'Rd', 'Ct', 'Dr', 'Av', 'Gr', 'Pde', 'Pl', 'Cr', 'Cl'], dtype='object')

# %%
melb_df['StreetType'] = street_types.apply(lambda x: x if x in popular_stypes else 'other')
display(melb_df['StreetType'])
# Out:
# 0           St
# 1           St
# 2           St
# 3        other
# 4           St
#          ...
# 13575       Cr
# 13576       Dr
# 13577       St
# 13578       St
# 13579       St
# Name: StreetType, Length: 13580, dtype: object

# %%
print(melb_df['StreetType'].nunique())
# 11
# Out:
# 11

# %%
melb_df = melb_df.drop('Address', axis=1)

# %%
display(melb_df)
# Out:
#               Suburb  Rooms Type      Price Method   SellerG       Date  \
# 0         Abbotsford      2    h  1480000.0      S    Biggin 2016-12-03
# 1         Abbotsford      2    h  1035000.0      S    Biggin 2016-02-04
# 2         Abbotsford      3    h  1465000.0     SP    Biggin 2017-03-04
# 3         Abbotsford      3    h   850000.0     PI    Biggin 2017-03-04
# 4         Abbotsford      4    h  1600000.0     VB    Nelson 2016-06-04
# ...              ...    ...  ...        ...    ...       ...        ...
# 13575  Wheelers Hill      4    h  1245000.0      S     Barry 2017-08-26
# 13576   Williamstown      3    h  1031000.0     SP  Williams 2017-08-26
# 13577   Williamstown      3    h  1170000.0      S     Raine 2017-08-26
# 13578   Williamstown      4    h  2500000.0     PI   Sweeney 2017-08-26
# 13579     Yarraville      4    h  1285000.0     SP   Village 2017-08-26
#
#        Distance  Postcode  Bedroom  ...  Lattitude  Longtitude  \
# ...

# %%
def get_weekend(weekday):
    if weekday == 5 or weekday == 6:
        return 1
    else:
        return 0

# %%
melb_df['Weekend'] = melb_df['WeekdaySale'].apply(get_weekend)
display(melb_df)
# Out:
#               Suburb  Rooms Type      Price Method   SellerG       Date  \
# 0         Abbotsford      2    h  1480000.0      S    Biggin 2016-12-03
# 1         Abbotsford      2    h  1035000.0      S    Biggin 2016-02-04
# 2         Abbotsford      3    h  1465000.0     SP    Biggin 2017-03-04
# 3         Abbotsford      3    h   850000.0     PI    Biggin 2017-03-04
# 4         Abbotsford      4    h  1600000.0     VB    Nelson 2016-06-04
# ...              ...    ...  ...        ...    ...       ...        ...
# 13575  Wheelers Hill      4    h  1245000.0      S     Barry 2017-08-26
# 13576   Williamstown      3    h  1031000.0     SP  Williams 2017-08-26
# 13577   Williamstown      3    h  1170000.0      S     Raine 2017-08-26
# 13578   Williamstown      4    h  2500000.0     PI   Sweeney 2017-08-26
# 13579     Yarraville      4    h  1285000.0     SP   Village 2017-08-26
#
#        Distance  Postcode  Bedroom  ...  Longtitude  \
# ...

# %%
melb_df[melb_df['Weekend'] == 1]['Price'].mean()
# Out:
# 1081198.6406956792

# %%
melb_df['SellerG'].value_counts()
# Out:
# Nelson           1565
# Jellis           1316
# hockingstuart    1167
# Barry            1011
# Ray               701
#                  ...
# Prowse              1
# Luxe                1
# Zahn                1
# Homes               1
# Point               1
# Name: SellerG, Length: 268, dtype: int64

# %%
popular_seller = melb_df['SellerG'].value_counts().nlargest(49).index
print(popular_seller)
# Index(['St', 'Rd', 'Ct
# Out:
# Index(['Nelson', 'Jellis', 'hockingstuart', 'Barry', 'Ray', 'Marshall',
#        'Buxton', 'Biggin', 'Brad', 'Fletchers', 'Woodards', 'Jas', 'Greg',
#        'McGrath', 'Sweeney', 'Noel', 'Miles', 'RT', 'Gary', 'Harcourts',
#        'Hodges', 'YPA', 'Stockdale', 'Village', 'Kay', 'Raine', 'Williams',
#        'Love', 'Douglas', 'Chisholm', 'RW', 'Rendina', 'HAR', 'O'Brien', 'C21',
#        'Collins', 'Cayzer', 'Eview', 'Purplebricks', 'Philip', 'Buckingham',
#        'Bells', 'Thomson', 'Nick', 'Alexkarbon', 'McDonald', 'Burnham',
#        'Moonee', 'LITTLE'],
#       dtype='object')

# %%
melb_df['SellerG'] = melb_df['SellerG'].apply(lambda x: x if x in popular_seller else 'other')
display(melb_df['SellerG'])

print(melb_df['SellerG'].nunique())
# Out:
# 0          Biggin
# 1          Biggin
# 2          Biggin
# 3          Biggin
# 4          Nelson
#            ...
# 13575       Barry
# 13576    Williams
# 13577       Raine
# 13578     Sweeney
# 13579     Village
# Name: SellerG, Length: 13580, dtype: object
# 50

# %%
result = (melb_df[melb_df['SellerG'] == 'Nelson']['Price'].min()) / (melb_df[melb_df['SellerG'] == 'other']['Price'].min())
print(result)
# Out:
# 1.297709923664122

# %%
# создаём пустой список
unique_list = []
# пробегаемся по именам столбцов в таблице
for col in melb_df.columns:
    # создаём кортеж (имя столбца, число уникальных значений)
    item = (col, melb_df[col].nunique(),melb_df[col].dtypes) 
    # добавляем кортеж в список
    unique_list.append(item) 
# создаём вспомогательную таблицу и сортируем её
unique_counts = pd.DataFrame(
    unique_list,
    columns=['Column_Name', 'Num_Unique', 'Type']
).sort_values(by='Num_Unique',  ignore_index=True)
# выводим её на экран
display(unique_counts)
# Out:
#         Column_Name  Num_Unique            Type
# 0           Weekend           2           int64
# 1              Type           3          object
# 2            Method           5          object
# 3       WeekdaySale           5           int64
# 4        Regionname           8          object
# 5          Bathroom           9           int64
# 6             Rooms           9           int64
# 7               Car          11           int64
# 8        StreetType          11          object
# 9           Bedroom          12           int64
# 10        MonthSale          12           int64
# 11      CouncilArea          33          object
# 12          SellerG          50          object
# 13             Date          58  datetime64[ns]
# 14      AgeBuilding         152           int64
# 15         Postcode         198           int64
# 16         Distance         202         float64
# 17    Propertycount         311           int64
# 18           Suburb         314          object
# ...

# %%
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
# ...

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] # список столбцов, которые мы не берём во внимание
max_unique_count = 150 # задаём максимальное число уникальных категорий
for col in melb_df.columns: # цикл по именам столбцов
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude: # проверяем условие
        melb_df[col] = melb_df[col].astype('category') # преобразуем тип столбца
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
print(melb_df['SellerG'].cat.categories)
# Out:
# Index(['Alexkarbon', 'Barry', 'Bells', 'Biggin', 'Brad', 'Buckingham',
#        'Burnham', 'Buxton', 'C21', 'Cayzer', 'Chisholm', 'Collins', 'Douglas',
#        'Eview', 'Fletchers', 'Gary', 'Greg', 'HAR', 'Harcourts', 'Hodges',
#        'Jas', 'Jellis', 'Kay', 'LITTLE', 'Love', 'Marshall', 'McDonald',
#        'McGrath', 'Miles', 'Moonee', 'Nelson', 'Nick', 'Noel', 'O'Brien',
#        'Philip', 'Purplebricks', 'RT', 'RW', 'Raine', 'Ray', 'Rendina',
#        'Stockdale', 'Sweeney', 'Thomson', 'Village', 'Williams', 'Woodards',
#        'YPA', 'hockingstuart', 'other'],
#       dtype='object')

# %%
display(melb_df['SellerG'].cat.codes)
# Out:
# 0         3
# 1         3
# 2         3
# 3         3
# 4        30
#          ..
# 13575     1
# 13576    45
# 13577    38
# 13578    42
# 13579    44
# Length: 13580, dtype: int8

# %%
melb_df['Type'] = melb_df['Type'].cat.rename_categories({
    'u': 'unit',
    't': 'townhouse',
    'h': 'house'
})
display(melb_df['Type'])
# Out:
# 0        house
# 1        house
# 2        house
# 3        house
# 4        house
#          ...
# 13575    house
# 13576    house
# 13577    house
# 13578    house
# 13579    house
# Name: Type, Length: 13580, dtype: category
# Categories (3, object): ['house', 'townhouse', 'unit']

# %%
new_houses_types = pd.Series(['unit', 'house', 'flat', 'flat', 'house'])
new_houses_types = new_houses_types.astype(melb_df['Type'].dtype)
display(new_houses_types)
# Out:
# 0     unit
# 1    house
# 2      NaN
# 3      NaN
# 4    house
# dtype: category
# Categories (3, object): ['house', 'townhouse', 'unit']

# %%
melb_df['Type'] = melb_df['Type'].cat.add_categories('flat')
new_houses_types = pd.Series(['unit', 'house', 'flat', 'flat', 'house'])
new_houses_types = new_houses_types.astype(melb_df['Type'].dtype)
display(new_houses_types)
# Out:
# 0     unit
# 1    house
# 2     flat
# 3     flat
# 4    house
# dtype: category
# Categories (4, object): ['house', 'townhouse', 'unit', 'flat']

# %%
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
popular_suburb = melb_df['Suburb'].value_counts().nlargest(119).index

melb_df['Suburb'] = melb_df['Suburb'].apply(lambda x: x if x in popular_suburb else 'other')
display(melb_df['Suburb'])

print(melb_df['Suburb'].nunique())
# Out:
# 0          Abbotsford
# 1          Abbotsford
# 2          Abbotsford
# 3          Abbotsford
# 4          Abbotsford
#              ...
# 13575           other
# 13576    Williamstown
# 13577    Williamstown
# 13578    Williamstown
# 13579      Yarraville
# Name: Suburb, Length: 13580, dtype: object
# 120

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] # список столбцов, которые мы не берём во внимание
max_unique_count = 150 # задаём максимальное число уникальных категорий
for col in melb_df.columns: # цикл по именам столбцов
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude: # проверяем условие
        melb_df[col] = melb_df[col].astype('category') # преобразуем тип столбца
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...
