# %%
import pandas as pd

melb_df = pd.read_csv('data/melb_data_fe.csv')
melb_df.head()
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
# ...

# %%
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  object
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'])

quarters = melb_df['Date'].dt.quarter
print(quarters.value_counts())
# Out:
# 3    4873
# 2    4359
# 4    2329
# 1    2019
# Name: Date, dtype: int64

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] # список столбцов, которые мы не берём во внимание
max_unique_count = 150 # задаём максимальное число уникальных категорий
for col in melb_df.columns: # цикл по именам столбцов
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude: # проверяем условие
        melb_df[col] = melb_df[col].astype('category') # преобразуем тип столбца
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_df.sort_values(by='Price').head(10)
# Out:
#                Suburb  Rooms   Type     Price Method        SellerG  \
# 2652        Footscray      1   unit   85000.0     PI        Burnham
# 1805            other      4  house  131000.0     PI          other
# 7303           Albion      1   unit  145000.0     PI         Biggin
# 1927           Coburg      4  house  145000.0     PI         Jellis
# 7940         Hawthorn      1   unit  160000.0     VB            HAR
# 12666       Brunswick      1   unit  170000.0     VB         Nelson
# 8811        Footscray      1   unit  170000.0     PI        Burnham
# 8504   West Footscray      1   unit  185000.0     PI            Jas
# 7293           Albion      1   unit  185000.0      S  hockingstuart
# 7305           Albion      2   unit  190000.0     SP        Burnham
#
#             Date  Distance  Postcode  Bedroom  ...  Longtitude  \
# 2652  2016-03-09       6.4      3011        1  ...   144.89000
# 1805  2017-02-25       8.9      3162        4  ...   145.02420
# ...

# %%
melb_df.sort_values(by='Date', ascending=False)
# Out:
#              Suburb  Rooms   Type      Price Method    SellerG       Date  \
# 11144     Northcote      4  house  1955000.0     SP    McGrath 2017-12-08
# 11217  Surrey Hills      3  house  1775000.0     PI     Jellis 2017-12-08
# 11206      St Kilda      4  house  1600000.0     VB       Gary 2017-12-08
# 11207    Strathmore      7  house  2000000.0     SP     Nelson 2017-12-08
# 11208    Strathmore      4  house  1610000.0      S      other 2017-12-08
# ...             ...    ...    ...        ...    ...        ...        ...
# 1555     Camberwell      4  house  2650000.0      S     Jellis 2016-03-09
# 4510       Oak Park      3  house   892000.0      S     Nelson 2016-03-09
# 4388      Northcote      3  house  1200000.0      S     Nelson 2016-03-09
# 6184   Surrey Hills      3  house  1205000.0      S  Fletchers 2016-01-28
# 6183   Surrey Hills      2   unit   813000.0      S  Fletchers 2016-01-28
#
#        Distance  Postcode  Bedroom  ...  Longtitude             Regionname  \
# ...

# %%
melb_df.sort_values(by=['Price', 'Distance']).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 2652        6.4    85000.0
# 7116        7.8   200000.0
# 5206       11.2   220000.0
# 7240        8.2   241000.0
# 2898       13.0   250000.0
# ...         ...        ...
# 13341       6.3  4060000.0
# 8591        1.5  4275000.0
# 1094       11.2  4700000.0
# 5801        6.1  5046000.0
# 251         6.3  5525000.0
#
# [1358 rows x 2 columns]

# %%
mask1 = melb_df['AreaRatio'] < -0.8
mask2 = melb_df['Type'] == 'townhouse'
mask3 = melb_df['SellerG'] == 'McGrath'
melb_df[mask1 & mask2 & mask3].sort_values(
    by=['Date', 'AreaRatio'],
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Date', 'AreaRatio']]
# Out:
#         Date  AreaRatio
# 0 2016-07-26  -0.974922
# 1 2016-09-24  -0.971831
# 2 2016-11-27  -0.953608
# 3 2016-12-11  -0.945946
# 4 2017-08-04  -0.947368
# 5 2017-08-04  -0.970874

# %%
melb_df.sort_values(
    by=['AreaRatio'],
    ignore_index=False,
    ascending=False
).iloc[1558]
# Out:
# Suburb                       Elsternwick
# Rooms                                  2
# Type                               house
# Price                           716000.0
# Method                                 S
# SellerG                    hockingstuart
# Date                 2017-03-06 00:00:00
# Distance                             7.2
# Postcode                            3185
# Bedroom                                2
# Bathroom                               1
# Car                                    1
# Landsize                             0.0
# BuildingArea                       126.0
# CouncilArea                    Glen Eira
# Lattitude                      -37.89438
# Longtitude                     145.00851
# Regionname         Southern Metropolitan
# Propertycount                       4898
# MeanRoomsSquare                     25.2
# AreaRatio                            1.0
# MonthSale                              3
# AgeBuilding                           47
# ...

# %%
melb_df['Type'].value_counts()
# Out:
# house        9449
# unit         3017
# townhouse    1114
# Name: Type, dtype: int64

# %%
melb_df[melb_df['Type'] == 'townhouse'][melb_df['Rooms'] > 2]
# Out:
# C:\Users\Евгений\AppData\Local\Temp\ipykernel_1772\1888480828.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   melb_df[melb_df['Type'] == 'townhouse'][melb_df['Rooms'] > 2]
#                Suburb  Rooms       Type      Price Method   SellerG  \
# 21         Abbotsford      3  townhouse   900000.0      S     other
# 38       Airport West      3  townhouse   840000.0     PI    Nelson
# 42       Airport West      3  townhouse   700000.0      S      Brad
# 56       Airport West      3  townhouse   700000.0     PI      Brad
# 67       Airport West      3  townhouse   540000.0     SP    Nelson
# ...               ...    ...        ...        ...    ...       ...
# 13437           other      4  townhouse   655000.0      S    Nelson
# 13485           other      4  townhouse  1655000.0      S    Buxton
# 13504  Mount Waverley      3  townhouse  1035000.0     SP   McGrath
# 13521  Port Melbourne      4  townhouse  2455000.0     SP  Marshall
# ...

# %%
melb_df[melb_df['Type'] == 'townhouse'][melb_df['Rooms'] > 2].sort_values(
    by=['Rooms', 'MeanRoomsSquare'],
    ascending=[True, False],
    ignore_index=False
).iloc[18]
# Out:
# C:\Users\Евгений\AppData\Local\Temp\ipykernel_1772\398997834.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   melb_df[melb_df['Type'] == 'townhouse'][melb_df['Rooms'] > 2].sort_values(
# Suburb                     Brighton East
# Rooms                                  3
# Type                           townhouse
# Price                          1300000.0
# Method                                PI
# SellerG                           Buxton
# Date                 2016-09-17 00:00:00
# Distance                            10.7
# Postcode                            3187
# Bedroom                                3
# Bathroom                               2
# Car                                    2
# Landsize                           337.0
# BuildingArea                       222.0
# CouncilArea                      Bayside
# Lattitude                       -37.9196
# Longtitude                      145.0205
# Regionname         Southern Metropolitan
# ...

# %%
melb_df.groupby(by='Type').mean()
# Out:
# C:\Users\Евгений\AppData\Local\Temp\ipykernel_1772\1287844458.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   melb_df.groupby(by='Type').mean()
#               Rooms         Price   Distance     Postcode   Bedroom  Bathroom  \
# Type
# house      3.260874  1.242665e+06  10.979479  3104.080643  3.229336  1.613822
# townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183  1.809695
# unit       1.963871  6.051275e+05   7.607391  3110.797481  1.966523  1.183295
#
#                 Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# Type
# house      1.772674  617.181924    152.162553 -37.803795  144.994700
# townhouse  1.555655  279.606822    134.649710 -37.815782  144.996489
# unit       1.128936  477.314219    102.235863 -37.823710  144.996363
#
# ...

# %%
melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Out:
# Regionname
# Western Victoria              29.8
# Eastern Victoria              25.2
# Northern Victoria             21.8
# South-Eastern Metropolitan    14.7
# Eastern Metropolitan           7.8
# Western Metropolitan           4.3
# Southern Metropolitan          0.7
# Northern Metropolitan          0.0
# Name: Distance, dtype: float64

# %%
melb_df.groupby('MonthSale')['Price'].agg(
    ['count', 'mean', 'max']
).sort_values(by='count', ascending=False)
# Out:
#            count          mean        max
# MonthSale
# 8           1850  1.056371e+06  6500000.0
# 7           1835  9.314698e+05  9000000.0
# 5           1644  1.097807e+06  8000000.0
# 6           1469  1.068981e+06  7650000.0
# 3           1408  1.146762e+06  5600000.0
# 4           1246  1.050479e+06  5500000.0
# 9           1188  1.126349e+06  6400000.0
# 10           854  1.135970e+06  6250000.0
# 11           750  1.142503e+06  5050000.0
# 12           725  1.144737e+06  5700000.0
# 2            333  1.169051e+06  4735000.0
# 1            278  9.397921e+05  5200000.0

# %%
melb_df.groupby('MonthSale')['Price'].agg('describe')
# Out:
#             count          mean            std       min       25%        50%  \
# MonthSale
# 1           278.0  9.397921e+05  577668.924214  170000.0  570500.0   795000.0
# 2           333.0  1.169051e+06  671564.357417  131000.0  710000.0  1020000.0
# 3          1408.0  1.146762e+06  709573.596867   85000.0  680000.0   945000.0
# 4          1246.0  1.050479e+06  591892.902979  145000.0  655000.0   905500.0
# 5          1644.0  1.097807e+06  668492.867996  145000.0  650000.0   905000.0
# 6          1469.0  1.068981e+06  606010.069052  222000.0  660000.0   900000.0
# 7          1835.0  9.314698e+05  537390.803161  190000.0  586750.0   800000.0
# 8          1850.0  1.056371e+06  619617.476541  160000.0  635000.0   892000.0
# 9          1188.0  1.126349e+06  608734.690742  170000.0  725000.0   980000.0
# 10          854.0  1.135970e+06  692950.251627  250000.0  652625.0   950000.0
# 11          750.0  1.142503e+06  703666.227892  240000.0  671750.0   950000.0
# ...

# %%
melb_df.groupby('Regionname')['SellerG'].agg(
    		['nunique', set]
)
# Out:
#                             nunique  \
# Regionname
# Eastern Metropolitan             26
# Eastern Victoria                 11
# Northern Metropolitan            40
# Northern Victoria                11
# South-Eastern Metropolitan       25
# Southern Metropolitan            38
# Western Metropolitan             34
# Western Victoria                  6
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {Biggin, Jellis, Woodards, Philip, McGrath, No...
# Eastern Victoria            {Fletchers, Harcourts, Ray, C21, Barry, McGrat...
# Northern Metropolitan       {Greg, Biggin, Jellis, Woodards, Philip, Alexk...
# Northern Victoria           {Ray, Barry, McDonald, McGrath, Buckingham, ot...
# South-Eastern Metropolitan  {Greg, Biggin, Jellis, Woodards, McGrath, Noel...
# Southern Metropolitan       {Greg, Biggin, Jellis, Woodards, Williams, Phi...
# ...

# %%
melb_df.groupby('Rooms')['Price'].mean()
# Out:
# Rooms
# 1     4.338245e+05
# 2     7.750812e+05
# 3     1.076081e+06
# 4     1.445282e+06
# 5     1.870260e+06
# 6     1.849366e+06
# 7     1.920700e+06
# 8     1.602750e+06
# 10    9.000000e+05
# Name: Price, dtype: float64

# %%
melb_df.groupby('Regionname')['Lattitude'].std()
# Out:
# Regionname
# Eastern Metropolitan          0.047890
# Eastern Victoria              0.147067
# Northern Metropolitan         0.049639
# Northern Victoria             0.084455
# South-Eastern Metropolitan    0.073411
# Southern Metropolitan         0.043080
# Western Metropolitan          0.051251
# Western Victoria              0.011579
# Name: Lattitude, dtype: float64

# %%
melb_df
# Out:
#              Suburb  Rooms   Type      Price Method   SellerG       Date  \
# 0        Abbotsford      2  house  1480000.0      S    Biggin 2016-03-12
# 1        Abbotsford      2  house  1035000.0      S    Biggin 2016-04-02
# 2        Abbotsford      3  house  1465000.0     SP    Biggin 2017-04-03
# 3        Abbotsford      3  house   850000.0     PI    Biggin 2017-04-03
# 4        Abbotsford      4  house  1600000.0     VB    Nelson 2016-04-06
# ...             ...    ...    ...        ...    ...       ...        ...
# 13575         other      4  house  1245000.0      S     Barry 2017-08-26
# 13576  Williamstown      3  house  1031000.0     SP  Williams 2017-08-26
# 13577  Williamstown      3  house  1170000.0      S     Raine 2017-08-26
# 13578  Williamstown      4  house  2500000.0     PI   Sweeney 2017-08-26
# 13579    Yarraville      4  house  1285000.0     SP   Village 2017-08-26
#
#        Distance  Postcode  Bedroom  ...  Longtitude  \
# ...

# %%
melb_df_summer_2017 = melb_df[melb_df['Date'] <= '2017-09-01']
melb_df_summer_2017 = melb_df[melb_df['Date'] >= '2017-05-01']
melb_df_summer_2017.sort_values(by='Date', ascending=True)
melb_df_summer_2017.sort_values(by='Date', ascending=True)
melb_df_summer_2017.groupby('SellerG')['Price'].sum().sort_values()
# Out:
# SellerG
# LITTLE             2742000.0
# Burnham            6550500.0
# Moonee             8023000.0
# Thomson            8332000.0
# Cayzer            10766000.0
# Alexkarbon        10985000.0
# Bells             11436000.0
# McDonald          14637500.0
# Rendina           18062276.0
# Douglas           21676000.0
# Buckingham        23949100.0
# Eview             24374500.0
# Nick              24675000.0
# C21               25750500.0
# Collins           26125000.0
# Chisholm          26544000.0
# Purplebricks      29557000.0
# Philip            30186300.0
# Love              31209500.0
# Village           31548000.0
# Williams          31659000.0
# O'Brien           36933008.0
# RW                38421500.0
# Raine             40084700.0
# HAR               40275500.0
# Gary              45433400.0
# Stockdale         49376800.0
# Sweeney           50017750.0
# Miles             58008000.0
# Hodges            62028500.0
# YPA               63245350.0
# ...

# %%
def first_word(text: str) -> str:
    new_text = text.split(' ')
    ap = "'"
    for i in new_text:
        if i.isalpha() == True:
            result = i
            break
        elif ap in i:
            result = i
            break
    return new_text

print(first_word(" a word "))

#print("Example:")
#print(first_word("Hello world"))

# These "asserts" are used for self-checking
#assert first_word("Hello world") == "Hello"
#assert first_word(" a word ") == "a"
#assert first_word("don't touch it") == "don't"
#assert first_word("greetings, friends") == "greetings"
#assert first_word("... and so on ...") == "and"
#assert first_word("hi") == "hi"

#print("The mission is done! Click 'Check Solution' to earn rewards!")
# Out:
# ['', 'a', 'word', '']

# %%
FIRST_TEN = ["one", "two", "three", "four", "five", "six", "seven", "eight", "nine"]
SECOND_TEN = [
    "ten",
    "eleven",
    "twelve",
    "thirteen",
    "fourteen",
    "fifteen",
    "sixteen",
    "seventeen",
    "eighteen",
    "nineteen",
]
OTHER_TENS = [
    "twenty",
    "thirty",
    "forty",
    "fifty",
    "sixty",
    "seventy",
    "eighty",
    "ninety",
]
HUNDRED = "hundred"


def checkio(num: int) -> str:
    a = str(num)
    if len(a) == 1:
        result = FIRST_TEN[int(a)-1]
    elif len(a) == 2 and a[0] == '1':
        result = SECOND_TEN[int(a)-10]
    elif len(a) == 2 and a[0] != '1' and a[1] == '0':
        result = OTHER_TENS[int(int(a[0]+'0')/10-2)]
    elif len(a) == 2 and a[0] != '1' and a[1] != '0':
        result = OTHER_TENS[int(int(a[0]+'0')/10-2)] + ' ' + FIRST_TEN[int(a[1])-1]
    elif len(a) == 3 and a[1] == '0' and a[2] == '0':
        result = FIRST_TEN[int(a[0])-1] + ' hundred'
    elif len(a) == 3 and a[1] == '0':
        result = FIRST_TEN[int(a[0])-1] + ' hundred ' + FIRST_TEN[int(a[2])-1]
    elif len(a) == 3 and a[1] == '1':
        result = FIRST_TEN[int(a[0])-1] + ' hundred ' + SECOND_TEN[int(a[1:])-10]
    elif len(a) == 3 and a[1] != '1' and a[2] == '0':
        result = FIRST_TEN[int(a[0])-1] + ' hundred ' + OTHER_TENS[int(int(a[1]+'0')/10-2)]
    elif len(a) == 3 and a[1] != '1' and a[1] != '0':
        result = FIRST_TEN[int(a[0])-1] + ' hundred ' + OTHER_TENS[int(int(a[1]+'0')/10-2)] + ' ' + FIRST_TEN[int(a[2])-1]  
    return result

# %%
print(checkio(940))
# Out:
# nine hundred forty

# %%
melb_df.pivot_table(
    values='BuildingArea',
    index='Type',
    columns='Rooms',
    aggfunc='median',
    fill_value=0
)
# Out:
# Rooms         1    2    3      4    5    6      7    8    10
# Type
# house      126.0  126  126  141.0  177  126  216.5  126  126
# townhouse   88.0  114  126  159.5  152    0    0.0    0    0
# unit        69.5  110  126  126.0    0  171    0.0  126    0

# %%
melb_df.pivot_table(
    values='Price',
    index='SellerG',
    columns='Type',
    aggfunc='median',
    fill_value=0
)
# Out:
# Type             house  townhouse    unit
# SellerG
# Alexkarbon     1036250     935000  560000
# Barry           830000     727500  502000
# Bells           692500     430500  457500
# Biggin         1151750     675000  548000
# Brad            875000     700000  465000
# Buckingham      830000     820000  553000
# Burnham         922500          0  305000
# Buxton         1323750    1030000  670000
# C21             836500     768750  625500
# Cayzer         1505000    1450000  707500
# Chisholm       1520000     950000  640000
# Collins        1566500     930000  592000
# Douglas         684000     500000  494500
# Eview           760000     597500  602000
# Fletchers      1390000    1238000  653000
# Gary           1370000     993500  550000
# Greg           1330000     900000  547500
# HAR             695000          0  518000
# Harcourts       740000     653750  500000
# Hodges         1500000    1105000  605500
# Jas             935000     699000  455000
# ...

# %%
movies = pd.read_csv('data\movies.csv')
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %%
ratings_1 = pd.read_csv('data/ratings1.csv')
ratings_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40001 entries, 0 to 40000
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   userId   40001 non-null  int64
#  1   movieId  40001 non-null  int64
#  2   rating   40001 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 937.7 KB

# %%
ratings_1.describe()
# Out:
#              userId        movieId        rating
# count  40001.000000   40001.000000  40001.000000
# mean     134.711282   18898.619035      3.575223
# std       79.664674   35885.863627      1.022768
# min        1.000000       1.000000      0.500000
# 25%       66.000000    1079.000000      3.000000
# 50%      132.000000    2746.000000      4.000000
# 75%      208.000000    7153.000000      4.000000
# max      274.000000  193587.000000      5.000000

# %%
dates_df = pd.read_csv('data/dates.csv')
dates_df_1 = dates_df.copy()
dates_df_1['date'] = pd.to_datetime(dates_df_1['date'], dayfirst=True)
year_dates_df_1 = dates_df_1['date'].dt.year
print(year_dates_df_1.value_counts())
# Out:
# 2000    10061
# 2017     8198
# 2007     7114
# 2016     6703
# 2015     6616
# 2018     6418
# 1996     6040
# 2005     5813
# 2012     4656
# 2008     4351
# 2009     4158
# 2006     4059
# 2003     4014
# 2001     3922
# 2002     3478
# 2004     3279
# 1999     2439
# 2010     2301
# 1997     1916
# 2011     1690
# 2013     1664
# 2014     1439
# 1998      507
# Name: date, dtype: int64

# %%
ratings_2 = pd.read_csv('data/ratings2.csv')

# %%
ratings = pd.concat([ratings_1, ratings_2],
    ignore_index=True)
display(ratings)
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100832     610   166534     4.0
# 100833     610   168248     5.0
# 100834     610   168250     5.0
# 100835     610   168252     5.0
# 100836     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
print('Число строк в таблице ratings: ', ratings.shape[0])
print('Число строк в таблице dates: ', dates_df.shape[0])
print(ratings.shape[0] == dates_df.shape[0])
# Out:
# Число строк в таблице ratings:  100837
# Число строк в таблице dates:  100836
# False

# %%
display(ratings_1.tail(1))
display(ratings_2.head(1))
# Out:
#        userId  movieId  rating
# 40000     274     5621     2.0
#    userId  movieId  rating
# 0     274     5621     2.0

# %%
ratings = ratings.drop_duplicates(ignore_index=True)
print('Число строк в таблице ratings: ', ratings.shape[0])
# Out:
# Число строк в таблице ratings:  100836

# %%
ratings_dates = pd.concat([ratings, dates_df], axis=1)
display(ratings_dates.tail(7))
# Out:
#         userId  movieId  rating                 date
# 100829     610   164179     5.0  2017-05-03 21:07:11
# 100830     610   166528     4.0  2017-05-04 06:29:25
# 100831     610   166534     4.0  2017-05-03 21:53:22
# 100832     610   168248     5.0  2017-05-03 22:21:31
# 100833     610   168250     5.0  2017-05-08 19:50:47
# 100834     610   168252     5.0  2017-05-03 21:19:12
# 100835     610   170875     3.0  2017-05-03 21:20:15

# %%
df1 = pd.DataFrame({"Name": ["Pankaj", "Lisa"], "Surname": ["Sobolev", "Krasnova"]})
df2 = pd.DataFrame({"Role": ["Admin", "Editor"]})
display(df2)
# Out:
#      Role
# 0   Admin
# 1  Editor

# %%
import pandas as pd
import os

os.listdir(path)

#def concat_user_files(path):
    #result   = pd.concat([ratings_1, ratings_2],
    #ignore_index=True)
#display(ratings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 4
#       1 import pandas as pd
#       2 import os
# ----> 4 os.listdir(path)
#       6 #def concat_user_files(path):
#       7     #result   = pd.concat([ratings_1, ratings_2],
#       8     #ignore_index=True)
#       9 #display(ratings)
#
# NameError: name 'path' is not defined

# %%
ratings_dates
# Out:
#         userId  movieId  rating                 date
# 0            1        1     4.0  2000-07-30 18:45:03
# 1            1        3     4.0  2000-07-30 18:20:47
# 2            1        6     4.0  2000-07-30 18:37:04
# 3            1       47     5.0  2000-07-30 19:03:35
# 4            1       50     5.0  2000-07-30 18:48:51
# ...        ...      ...     ...                  ...
# 100831     610   166534     4.0  2017-05-03 21:53:22
# 100832     610   168248     5.0  2017-05-03 22:21:31
# 100833     610   168250     5.0  2017-05-08 19:50:47
# 100834     610   168252     5.0  2017-05-03 21:19:12
# 100835     610   170875     3.0  2017-05-03 21:20:15
#
# [100836 rows x 4 columns]

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
joined_false = ratings_dates.join(
    movies,
    rsuffix='_right',
    how='left'
)
display(joined_false)
# Out:
#         userId  movieId  rating                 date  movieId_right  \
# 0            1        1     4.0  2000-07-30 18:45:03            1.0
# 1            1        3     4.0  2000-07-30 18:20:47            2.0
# 2            1        6     4.0  2000-07-30 18:37:04            3.0
# 3            1       47     5.0  2000-07-30 19:03:35            4.0
# 4            1       50     5.0  2000-07-30 18:48:51            5.0
# ...        ...      ...     ...                  ...            ...
# 100831     610   166534     4.0  2017-05-03 21:53:22            NaN
# 100832     610   168248     5.0  2017-05-03 22:21:31            NaN
# 100833     610   168250     5.0  2017-05-08 19:50:47            NaN
# 100834     610   168252     5.0  2017-05-03 21:19:12            NaN
# 100835     610   170875     3.0  2017-05-03 21:20:15            NaN
#
#                                      title  \
# 0                         Toy Story (1995)
# 1                           Jumanji (1995)
# ...

# %%
joined = ratings_dates.join(
    movies.set_index('movieId'),
    on='movieId',
    how='left'
)
display(joined.head())
# Out:
#    userId  movieId  rating                 date                        title  \
# 0       1        1     4.0  2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0  2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0  2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0  2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
merged = ratings_dates.merge(
    movies,
    on='movieId',
    how='left'
)
display(merged.head())
# Out:
#    userId  movieId  rating                 date                        title  \
# 0       1        1     4.0  2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0  2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0  2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0  2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
print('Число строк в таблице ratings_dates: ', ratings_dates.shape[0])
print('Число строк в таблице merged: ', merged.shape[0])
print(ratings_dates.shape[0] == merged.shape[0])
# Out:
# Число строк в таблице ratings_dates:  100836
# Число строк в таблице merged:  100836
# True

# %%
merge_ratings = ratings_1.merge(ratings_2, how='outer')
print('Число строк в таблице merge_ratings: ', merge_ratings.shape[0])
display(merge_ratings)
# Число строк в таблице merge_ratings: 100836
# Out:
# Число строк в таблице merge_ratings:  100836
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100831     610   166534     4.0
# 100832     610   168248     5.0
# 100833     610   168250     5.0
# 100834     610   168252     5.0
# 100835     610   170875     3.0
#
# [100836 rows x 3 columns]

# %%
ratings_movies = pd.read_csv('data/ratings_movies.csv')
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None
    
ratings_movies['year_release'] = ratings_movies['title'].apply(get_year_release)
ratings_movies['year_release']
ratings_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    100836 non-null  int64
#  1   userId        100836 non-null  int64
#  2   movieId       100836 non-null  int64
#  3   rating        100836 non-null  float64
#  4   date          100836 non-null  object
#  5   title         100836 non-null  object
#  6   genres        100836 non-null  object
#  7   year_release  100818 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 6.2+ MB

# %%
ratings_movies[ratings_movies['year_release'] == 1999].groupby('title')['rating'].mean().sort_values()
# Out:
# title
# Bloodsport: The Dark Kumite (1999)            0.5
# Simon Sez (1999)                              1.0
# Chill Factor (1999)                           1.0
# Source, The (1999)                            1.0
# Trippin' (1999)                               1.0
#                                              ...
# Trailer Park Boys (1999)                      5.0
# Larry David: Curb Your Enthusiasm (1999)      5.0
# Sun Alley (Sonnenallee) (1999)                5.0
# George Carlin: You Are All Diseased (1999)    5.0
# Five Senses, The (1999)                       5.0
# Name: rating, Length: 261, dtype: float64

# %%
joined.groupby('userId')['genres'].nunique().sort_values(ascending=False)
# Out:
# userId
# 599    524
# 414    482
# 448    403
# 380    399
# 474    395
#       ...
# 578     15
# 12      15
# 85      13
# 214     13
# 245     13
# Name: genres, Length: 610, dtype: int64

# %%
ratings_movies.groupby('userId')['rating'].agg(['count', 'mean']).sort_values(['count', 'mean'], ascending=[True, False]).head(20)
# Out:
#         count      mean
# userId
# 53         20  5.000000
# 595        20  4.200000
# 189        20  4.100000
# 569        20  4.000000
# 278        20  3.875000
# 320        20  3.525000
# 194        20  3.475000
# 147        20  3.375000
# 406        20  3.250000
# 257        20  3.200000
# 576        20  3.100000
# 207        20  2.875000
# 431        20  2.725000
# 442        20  1.275000
# 49         21  4.261905
# 364        21  4.190476
# 37         21  4.142857
# 547        21  4.142857
# 439        21  4.119048
# 87         21  3.952381

# %%
ratings_movies[ratings_movies['year_release'] == 2018].groupby('genres')['rating'].agg(['mean', 'count']).sort_values(['mean', 'count'], ascending=[False, False]).head(50)
# Out:
#                                             mean  count
# genres
# Adventure|Comedy|Fantasy                4.500000      1
# Adventure|Thriller                      4.500000      1
# Comedy|Fantasy|Sci-Fi                   4.500000      1
# Comedy|Romance                          4.500000      1
# Documentary                             4.000000      2
# Action|Comedy|Crime|Horror              4.000000      1
# Action|Crime|Drama|Thriller             4.000000      1
# Action|Adventure|Sci-Fi                 3.928571     14
# Action|Adventure|Children|Sci-Fi        3.900000      5
# Action|Comedy|Sci-Fi                    3.875000     12
# Adventure|Mystery|Sci-Fi|Thriller       3.833333      3
# Action|Adventure|Thriller               3.750000      2
# Action|Adventure|Comedy|Fantasy|Sci-Fi  3.666667      3
# Animation|Comedy                        3.500000      5
# Action|Animation                        3.500000      1
# Action|Mystery|Sci-Fi|Thriller          3.500000      1
# ...

# %%
ratings_movies['date'] = pd.to_datetime(ratings_movies['date'], dayfirst=False)
ratings_movies['year_rating'] = ratings_movies['date'].dt.year
new_ratings_movies = ratings_movies.pivot_table(
    values='rating',
    index='genres',
    columns='year_rating',
    fill_value=0
)
new_ratings_movies.loc['Action|Adventure'].min()
new_ratings_movies.loc['Action|Adventure|Animation|Children|Comedy|IMAX']
new_ratings_movies.loc['Animation|Children|Mystery']
new_ratings_movies.loc['Comedy']
# Out:
# year_rating
# 1996    3.228571
# 1997    3.409091
# 1998    3.000000
# 1999    3.606061
# 2000    3.141291
# 2001    3.318408
# 2002    3.198556
# 2003    3.120066
# 2004    3.356877
# 2005    2.963325
# 2006    3.347534
# 2007    2.928187
# 2008    3.426667
# 2009    3.273292
# 2010    3.179825
# 2011    3.232877
# 2012    3.478477
# 2013    3.489474
# 2014    3.271429
# 2015    3.106183
# 2016    3.373431
# 2017    2.852668
# 2018    3.121296
# Name: Comedy, dtype: float64

# %%
orders = pd.read_csv('data/orders.csv', sep=';')
orders
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
products = pd.read_csv('data/products.csv', sep=';')
products
# Out:
#     Product_ID                                   Name  Price CURRENCY
# 0           47                   Шатны Полосатый рейс   2999      RUR
# 1           51               Платье Аленький цветочек   4999      RUR
# 2           53                 Штаны Цветочная Поляна   4999      RUR
# 3           71                    Платье Ночная Жизнь   7999      RUR
# 4           74               Платье Ночная Жизнь XXXL   8999      RUR
# 5           86                     Носки Простые, муж     45      RUR
# 6           91                     Носки Честные, муж     50      RUR
# 7          103                  Носки Подарочные, муж    199      RUR
# 8          104                  Носки Подарочные, жен    249      RUR
# 9          124                   Носки беговые Camino    999      RUR
# 10         137              Гольфы детские Снегурочка     99      RUR
# 11         138               Гольфы детские Питер Пен     99      RUR
# ...

# %%
orders_products = orders.merge(products, how='left', left_on='ID товара', right_on='Product_ID')
orders_products
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
orders_products['Сумма продаж'] = orders_products['Количество'] * orders_products['Price']
orders_products[orders_products['Оплачен'] == 'Да']
orders_products.groupby('ID Покупателя')['Сумма продаж'].max()
# Out:
# ID Покупателя
# 1     1245.0
# 5     7999.0
# 7     8999.0
# 8     1743.0
# 9     4500.0
# 10     995.0
# Name: Сумма продаж, dtype: float64
